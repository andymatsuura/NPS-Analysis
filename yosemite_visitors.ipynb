# %%
import pandas as pd

# %%
yosemite_visitors = pd.read_csv("Resources/yosemite.csv")
yosemite_visitors
# Out:
#           Title1 Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0    Yosemite NP        NaN        NaN        NaN              NaN
# 1            NaN        NaN        NaN        NaN              NaN
# 2         Field1     Field2     Field3     Field4  RecreationHours
# 3           1979    January     72,701      3,053        2,098,509
# 4           1979   February     72,926      3,030        2,098,838
# ..           ...        ...        ...        ...              ...
# 526         2022     August    518,407     18,927        8,568,440
# 527         2022  September    424,374     15,920        6,137,404
# 528         2022    October    381,612     14,251        5,418,446
# 529         2022   November    178,786      7,773        2,634,129
# 530         2022   December    131,100      5,758        1,810,470
#
#              Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                   NaN        NaN        NaN        NaN        NaN  ...
# ...

# %%
yosemite_visitors.rename(columns={
    "Title1": "Year",
    "Unnamed: 1": "Month",
    "Unnamed: 2": "Recreation Visitors", 
    "Unnamed: 3": "Non-Recreation Visitors",
    "
})
# Out:
#             Year      Month Recreation Visitors Unnamed: 3       Unnamed: 4  \
# 0    Yosemite NP        NaN                 NaN        NaN              NaN
# 1            NaN        NaN                 NaN        NaN              NaN
# 2         Field1     Field2              Field3     Field4  RecreationHours
# 3           1979    January              72,701      3,053        2,098,509
# 4           1979   February              72,926      3,030        2,098,838
# ..           ...        ...                 ...        ...              ...
# 526         2022     August             518,407     18,927        8,568,440
# 527         2022  September             424,374     15,920        6,137,404
# 528         2022    October             381,612     14,251        5,418,446
# 529         2022   November             178,786      7,773        2,634,129
# 530         2022   December             131,100      5,758        1,810,470
#
# ...
