# %%
import requests
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
import matplotlib.pyplot as plt
from apikeys import nps_key
from apikeys import weather_key
from pprint import pprint

# %%
url = "https://developer.nps.gov/api/v1/parks?api_key=" + nps_key

# %%
response = requests.get(url)

# %%
response_json = response.json()

# %%
weather_url = "https://api.weather.gov/alerts?active=false&status=actual&message_type=alert&limit=500"

# %%
response_w = requests.get(weather_url)
w_json = response_w.json()
w_json
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    '@vocab': 'https://api.weather.gov/ontology#'}],
#  'type': 'FeatureCollection',
#  'features': [{'id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.9af3b0efc4e9d07c5ab014a65b46caf6f764a277.001.1',
#    'type': 'Feature',
#    'geometry': None,
#    'properties': {'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.9af3b0efc4e9d07c5ab014a65b46caf6f764a277.001.1',
#     '@type': 'wx:Alert',
#     'id': 'urn:oid:2.49.0.1.840.0.9af3b0efc4e9d07c5ab014a65b46caf6f764a277.001.1',
#     'areaDesc': 'Sheridan; Burleigh; Kidder; Stutsman; Logan; La Moure',
#     'geocode': {'SAME': ['038083',
#       '038015',
#       '038043',
#       '038093',
#       '038047',
#       '038045'],
#      'UGC': ['NDZ022', 'NDZ035', 'NDZ036', 'NDZ037', 'NDZ047', 'NDZ048']},
# ...
