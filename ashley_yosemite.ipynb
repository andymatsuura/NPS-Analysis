# %%
import pandas as pd

# %%
yosemite_df = pd.read_csv("Resources/yosemite_data.csv", skiprows=2)
yosemite_df
# Out:
#      Field1     Field2   Field3  Field4 RecreationHours NonRecreationHours  \
# 0      1979    January   72,701   3,053       2,098,509             87,519
# 1      1979   February   72,926   3,030       2,098,838             86,785
# 2      1979      March   87,950   3,751       2,511,342            105,268
# 3      1979      April  136,275   5,477       3,897,346            152,005
# 4      1979        May  210,756   7,765       5,805,477            204,231
# ..      ...        ...      ...     ...             ...                ...
# 523    2022     August  518,407  18,927       8,568,440            446,062
# 524    2022  September  424,374  15,920       6,137,404            389,778
# 525    2022    October  381,612  14,251       5,418,446            348,997
# 526    2022   November  178,786   7,773       2,634,129            214,985
# 527    2022   December  131,100   5,758       1,810,470            161,336
#
# ...
